# %%
import requests
import os

stock_price_api = os.getenv('STOCK_PRICE_API')
weather_api = os.getenv('WEATHER_API_KEY')

# %%
weather_api
# Out:
# 'ed95ad367f5048a7ade95407263001'

# %%
symbol = 'AAPL'
stock_price = requests.get(f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={symbol}&apikey={stock_price_api}')
print(stock_price.json())
# Out:
# {'Global Quote': {'01. symbol': 'AAPL', '02. open': '258.0000', '03. high': '259.6500', '04. low': '254.4100', '05. price': '258.2800', '06. volume': '67253009', '07. latest trading day': '2026-01-29', '08. previous close': '256.4400', '09. change': '1.8400', '10. change percent': '0.7175%'}}

# %%
json = {
    'key': 'ed95ad367f5048a7ade95407263001',
    'q':'Jodhpur'
}
weather = requests.post('http://api.weatherapi.com/v1/current.json', data=json)
weather.json()
# Out:
# {'location': {'name': 'Jodhpur',
#   'region': 'Rajasthan',
#   'country': 'India',
#   'lat': 26.2867,
#   'lon': 73.03,
#   'tz_id': 'Asia/Kolkata',
#   'localtime_epoch': 1769770193,
#   'localtime': '2026-01-30 16:19'},
#  'current': {'last_updated_epoch': 1769769900,
#   'last_updated': '2026-01-30 16:15',
#   'temp_c': 25.9,
#   'temp_f': 78.6,
#   'is_day': 1,
#   'condition': {'text': 'Sunny',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#    'code': 1000},
#   'wind_mph': 2.7,
#   'wind_kph': 4.3,
#   'wind_degree': 66,
#   'wind_dir': 'ENE',
#   'pressure_mb': 1014.0,
#   'pressure_in': 29.94,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 18,
#   'cloud': 11,
#   'feelslike_c': 24.4,
#   'feelslike_f': 75.9,
#   'windchill_c': 25.9,
#   'windchill_f': 78.6,
#   'heatindex_c': 24.4,
#   'heatindex_f': 75.9,
#   'dewpoint_c': 0.0,
#   'dewpoint_f': 32.0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 0.9,
#   'gust_mph': 3.4,
# ...
